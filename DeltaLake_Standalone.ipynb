# %%
# %pip install pyarrow deltalake
# %pip install -q kaggle
# %pip install polars

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d cisautomotiveapi/large-car-dataset
# Out:
# ...
#  99% 816M/825M [00:09<00:00, 101MB/s]
# 100% 825M/825M [00:09<00:00, 90.9MB/s]

# %%
# !unzip /content/large-car-dataset.zip
# Out:
# Archive:  /content/large-car-dataset.zip
#   inflating: CIS_Automotive_Kaggle_Sample.csv

# %%
# !pip install 'modin[all]'

# %%
# import modin.pandas as pd
# import ray
# ray.init()

# df=pd.read_csv(r'/content/CIS_Automotive_Kaggle_Sample.csv')
# df.head()

# %%
import polars as pl

df=pl.read_csv(r'/content/CIS_Automotive_Kaggle_Sample.csv',dtypes={'vf_MakeID': str})
print(df.shape)
df.head()

# %%
df.shape

# %% [markdown]
# # Delta Lake

# %%
# Writing a Delta Table with Pandas
from deltalake.writer import write_deltalake

write_deltalake('tables/foo', df, mode='overwrite')

# %%
# print working directory
# !pwd

# List files and folders
# !ls

# Check the open jdk version on colab
# !ls /usr/lib/jvm/
# Out:
# /content
# sample_data
# java-1.11.0-openjdk-amd64  java-11-openjdk-amd64

# %%
# # Download and install Java 8
# !apt-get update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# Download Apache Spark binary: This link can change based on the version. Update this link with the latest version before using
# !wget -q https://downloads.apache.org/spark/spark-3.4.2/spark-3.4.2-bin-hadoop3.tgz

# %%
# Unzip file
# !tar -xvzf /content/spark-3.4.2-bin-hadoop3.tgz

# %%
# # Install findspark: Adds Pyspark to sys.path at runtime
# !pip install -q findspark

# # Install pyspark
# !pip install pyspark

# %%
# import findspark
# findspark.init()

# %%
# Add environmental variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.2-bin-hadoop3"

# findspark will locate spark in the system
# import findspark
# findspark.init()

# %%
# from pyspark.sql import SparkSession

# spark = SparkSession.builder \
#         .master("local") \
#         .appName("Hands-on PySpark on Google Colab") \
#         .getOrCreate()


# spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://4e5d53af038a:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Hands-on PySpark on Google Colab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# spark.sparkContext
# Out:
# <SparkContext master=local appName=Hands-on PySpark on Google Colab>

# %%
# spark_data = spark.read.format('csv').options(header='true').load("/content/CIS_Automotive_Kaggle_Sample.csv")
# spark_data.show(5, truncate=False)
# Out:
# +----------------------------------------------------------------+--------+----------+----------+-----+--------+-------+-----+-------------------+-------------+----------+--------------+--------+--------+----------------------+------------------------+----------------------+---------------------+----------------------+-------------------+----------------------------+----------------------------+-----------------------+----------------------------+--------------------+-----------------------------------+--------------------+--------+------------+-----------+--------------+---------------+--------------+-------------+----------------+-----------------+---------------+--------------+-----------+--------------+--------------+--------------+---------------+--------------------------+-------------------------------------------------------+------------------+------------------+---------------------+------------+--------------+-----------+--------+------------------+---------------+---------
# ...

# %%
# spark_data.count()
# Out:
# 5695016

# %%
# %%spark
#
# // Scala code starts here
# import org.apache.spark.sql._
#
# // Create SparkSession
# val spark = SparkSession.builder()
#   .appName("Spark in Colab")
#   .master("local[*]")
#   .getOrCreate()
#
# // Read CSV
# val df = spark.read
#   .format("csv")
#   .option("header", "true")
#   .load("/content/CIS_Automotive_Kaggle_Sample.csv")
#
# // Create a temporary view
# df.createOrReplaceTempView("my_table")
# Out:
# UsageError: Cell magic `%%spark` not found.

# %%
# !wget -O models/ldm/inpainting_big/last.ckpt https://heibox.uni-heidelberg.de/f/4d9ac7ea40c64582b7c9/?dl=1
# Out:
# models/ldm/inpainting_big/last.ckpt: No such file or directory

# %%
# %%writefile Example.scala
# // This is a Scala source file named Example.scala
#
# object Example {
#   def main(args: Array[String]): Unit = {
#     println("Hello, Scala!")
#   }
# }
# Out:
# Writing Example.scala

# %%
# Read the Scala code from the uploaded file
with open("Example.scala", "r") as file:
    scala_code = file.read()

# Run the Scala code using Spark
spark._jvm.scala.tools.nsc.MainGenericRunner.run_scala(None, scala_code.split())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-77b0fcf0e864> in <cell line: 6>()
#       4
#       5 # Run the Scala code using Spark
# ----> 6 spark._jvm.scala.tools.nsc.MainGenericRunner.run_scala(None, scala_code.split())
#
# NameError: name 'spark' is not defined
